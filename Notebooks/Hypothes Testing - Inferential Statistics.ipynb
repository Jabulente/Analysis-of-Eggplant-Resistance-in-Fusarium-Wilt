# %% [markdown]
# <h1 style='font-size: 35px; color: crimson; font-family: Colonna MT; font-weight: 600; text-align: center'>Hypothes Testing | Inferential Statistics</h1>
#
# ---

# %% [markdown]
# <h1 style=' font-weight: 600; font-size: 20px; text-align: left'>1.0. Import Required Libraries</h1>

# %%
# Statistical Analysis and Statistical Modeling
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import numpy as np
import sys
import re
import os


pd.set_option('display.max_columns', 70) 
pd.set_option('display.float_format', lambda x: '%.2f' % x)
print("....Libraries Loaded Successfully....")
# Out:
# ....Libraries Loaded Successfully....

# %% [markdown]
# <h1 style='font-weight: 600; font-size: 18px; text-align: left'>2.0. Import and Preprocessing Dataset</h1>

# %%
filepath = "../Datasets/Eggplant Fusarium Fresistance Data.csv"
df = pd.read_csv(filepath)
display(df)
# Out:
#     Variety Resistance Level  Replication ID  Infection Severity (%)  \
# 0     EP-R1        Resistant               1                   22.50
# 1     EP-R1        Resistant               2                   27.90
# 2     EP-R1        Resistant               3                   21.20
# 3     EP-R1        Resistant               4                   15.50
# 4     EP-R1        Resistant               5                   17.30
# ..      ...              ...             ...                     ...
# 795   EP-S3      Susceptible              96                   75.20
# 796   EP-S3      Susceptible              97                   74.80
# 797   EP-S3      Susceptible              98                   58.10
# 798   EP-S3      Susceptible              99                   54.10
# 799   EP-S3      Susceptible             100                   73.50
#
#      Wilt index  Plant height (cm)  Days to wilt symptoms  Survival rate (%)  \
# 0          0.70              88.90                     21              88.80
# 1          1.20              82.20                     19              87.70
# 2          0.00              74.70                     17              84.90
# 3          0.10              93.80                     18              90.30
# 4          0.90              78.10                     19              87.00
# ..          ...                ...                    ...                ...
# 795        3.60              68.20                      7               6.40
# 796        4.90              59.50                      4              27.20
# 797        3.60              78.80                      7              30.80
# 798        4.10              63.70                      7              24.10
# 799        3.40              67.40                      5               8.60
#
#      Disease incidence (%)
# 0                    23.40
# 1                    21.70
# 2                    27.20
# 3                    15.00
# 4                    23.00
# ..                     ...
# 795                  85.50
# 796                  82.00
# 797                  75.40
# 798                  81.80
# 799                  85.20
#
# [800 rows x 9 columns]

# %% [markdown]
# <h1 style='font-weight: 600; font-size: 20px; text-align: left'>5.0. Hypothes Testing (Inferential Statistics)</h1>

# %% [markdown]
# <h4 style='font-size: 15px;  font-weight: 600'>5.1: Group-wise Comparatives Analysis of Continuous variables</h4>
#
# Now, let’s turn our attention to comparing the means of variables across different specified groups. By grouping the data based on a categorical feature, we can calculate the mean of each continuous variable within each group. This allows us to identify differences or similarities in average values between groups, offering insights into how the variable behaves under different conditions or categories.

# %%
def summary_stats(df, group):
    Metrics = df.select_dtypes(include=np.number).columns.tolist()
    df_without_location = df.drop(columns=[group])
    grand_mean = df_without_location[Metrics].mean()
    sem = df_without_location[Metrics].sem()
    cv = df_without_location[Metrics].std() / df_without_location[Metrics].mean() * 100
    grouped = df.groupby(group)[Metrics].agg(['mean', 'sem']).reset_index()
    
    summary_df = pd.DataFrame()
    for col in Metrics:
        summary_df[col] = grouped.apply(
            lambda x: f"{x[(col, 'mean')]:.2f} ± {x[(col, 'sem')]:.2f}", axis=1
        )
    
    summary_df.insert(0, group, grouped[group])
    grand_mean_row = ['Grand Mean'] + grand_mean.tolist()
    sem_row = ['SEM'] + sem.tolist()
    cv_row = ['%CV'] + cv.tolist()
    
    summary_df.loc[len(summary_df)] = grand_mean_row
    summary_df.loc[len(summary_df)] = sem_row
    summary_df.loc[len(summary_df)] = cv_row
    
    return summary_df

results = summary_stats(df, group='Variety')
results
# Out:
#        Variety Replication ID Infection Severity (%)   Wilt index  \
# 0        EP-M1   50.50 ± 2.90           44.16 ± 1.06  2.56 ± 0.07
# 1        EP-M2   50.50 ± 2.90           45.44 ± 1.01  2.51 ± 0.07
# 2        EP-R1   50.50 ± 2.90           20.69 ± 0.43  0.73 ± 0.05
# 3        EP-R2   50.50 ± 2.90           20.81 ± 0.46  0.83 ± 0.05
# 4        EP-R3   50.50 ± 2.90           20.89 ± 0.42  0.82 ± 0.05
# 5        EP-S1   50.50 ± 2.90           75.26 ± 1.08  4.20 ± 0.06
# 6        EP-S2   50.50 ± 2.90           73.99 ± 0.91  4.11 ± 0.05
# 7        EP-S3   50.50 ± 2.90           73.91 ± 0.89  4.18 ± 0.06
# 8   Grand Mean          50.50                  46.89         2.49
# 9          SEM           1.02                   0.87         0.06
# 10         %CV          57.20                  52.63        63.01
#
#    Plant height (cm) Days to wilt symptoms Survival rate (%)  \
# 0       74.44 ± 0.51          11.99 ± 0.15      54.57 ± 1.00
# 1       75.18 ± 0.44          11.85 ± 0.16      55.77 ± 1.00
# 2       84.80 ± 0.59          17.97 ± 0.19      89.25 ± 0.52
# 3       85.33 ± 0.60          17.98 ± 0.20      90.49 ± 0.46
# 4       84.84 ± 0.58          18.51 ± 0.20      89.61 ± 0.47
# 5       65.22 ± 0.50           6.82 ± 0.12      24.14 ± 0.80
# 6       65.47 ± 0.54           6.91 ± 0.10      24.66 ± 0.89
# 7       64.71 ± 0.53           6.76 ± 0.12      24.44 ± 0.75
# 8              75.00                 12.35             56.62
# 9               0.36                  0.18              1.04
# 10             13.51                 41.81             51.84
#
#    Disease incidence (%)
# 0           50.54 ± 0.79
# 1           51.75 ± 1.02
# 2           25.84 ± 0.72
# 3           26.17 ± 0.78
# 4           25.25 ± 0.70
# 5           81.24 ± 0.75
# 6           79.57 ± 0.65
# 7           80.79 ± 0.61
# 8                  52.64
# 9                   0.88
# 10                 47.36

# %%
results = summary_stats(df, group='Resistance Level')
results.T
# Out:
#                                    0             1             2           3  \
# Resistance Level            Moderate     Resistant   Susceptible  Grand Mean
# Replication ID          50.50 ± 2.05  50.50 ± 1.67  50.50 ± 1.67       50.50
# Infection Severity (%)  44.80 ± 0.73  20.80 ± 0.25  74.38 ± 0.56       46.89
# Wilt index               2.53 ± 0.05   0.79 ± 0.03   4.16 ± 0.03        2.49
# Plant height (cm)       74.81 ± 0.33  84.99 ± 0.34  65.13 ± 0.30       75.00
# Days to wilt symptoms   11.92 ± 0.11  18.15 ± 0.12   6.83 ± 0.06       12.35
# Survival rate (%)       55.17 ± 0.71  89.78 ± 0.28  24.42 ± 0.47       56.62
# Disease incidence (%)   51.15 ± 0.64  25.75 ± 0.42  80.53 ± 0.39       52.64
#
#                           4     5
# Resistance Level        SEM   %CV
# Replication ID         1.02 57.20
# Infection Severity (%) 0.87 52.63
# Wilt index             0.06 63.01
# Plant height (cm)      0.36 13.51
# Days to wilt symptoms  0.18 41.81
# Survival rate (%)      1.04 51.84
# Disease incidence (%)  0.88 47.36

# %% [markdown]
# <h4 style='font-size: 15px; font-weight: 600'>5.3: Analysis of Varience (One Way ANOVA)</h4>
#
#
# A one-way ANOVA (Analysis of Variance) is a statistical test used to determine if there are significant differences between the means of three or more independent groups based on a single factor (or independent variable). It assesses whether the factor has an effect on the dependent variable. If the p-value from the test is less than a specified significance level (usually 0.05), it suggests that at least one group mean is significantly different from the others.

# %%
def rename(text): return re.sub(r'[^a-zA-Z]', "", text)
    
def One_way_anova(data, Metrics, group_cols):
    results = []
    original_group_cols = group_cols[:]  # Save original names for reporting
    group_cols = [rename(col) for col in group_cols]
    data = data.rename(columns={col: rename(col) for col in data.columns})
    
    for original_group, group in zip(original_group_cols, group_cols):
        for col in Metrics:
            column_name = rename(col)  
            formula = f"{column_name} ~ C({group})" 
            model = smf.ols(formula, data=data).fit()
            anova_table = sm.stats.anova_lm(model, typ=2)
            
            for source, row in anova_table.iterrows():
                p_value = row["PR(>F)"]
                interpretation = "Significant" if p_value < 0.05 else "No significant"
                if source == "Residual":
                    interpretation = "-"
                
                results.append({
                    "Variable": col,
                    #"Factor": original_group,  # Use original name here
                    "Source": source,
                    "Sum Sq": row["sum_sq"],
                    "df": row["df"],
                    "F-Value": row["F"],
                    "p-Value": p_value,
                    "Interpretation": interpretation
                })

    return pd.DataFrame(results)

group_cols = ['Variety', 'Resistance Level']
Metrics = ['Infection Severity (%)', 'Wilt index', 'Plant height (cm)', 'Days to wilt symptoms', 'Survival rate (%)', 'Disease incidence (%)']
Anova_results = One_way_anova(df, Metrics, group_cols)
Anova_results
# Out:
#                   Variable              Source    Sum Sq     df  F-Value  \
# 0   Infection Severity (%)          C(Variety) 432094.82   7.00   897.47
# 1   Infection Severity (%)            Residual  54473.51 792.00      NaN
# 2               Wilt index          C(Variety)   1705.22   7.00   730.61
# 3               Wilt index            Residual    264.07 792.00      NaN
# 4        Plant height (cm)          C(Variety)  59239.97   7.00   293.62
# 5        Plant height (cm)            Residual  22827.23 792.00      NaN
# 6    Days to wilt symptoms          C(Variety)  19302.91   7.00  1091.56
# 7    Days to wilt symptoms            Residual   2000.79 792.00      NaN
# 8        Survival rate (%)          C(Variety) 641645.80   7.00  1559.68
# 9        Survival rate (%)            Residual  46546.44 792.00      NaN
# 10   Disease incidence (%)          C(Variety) 450964.12   7.00  1114.18
# 11   Disease incidence (%)            Residual  45794.66 792.00      NaN
# 12  Infection Severity (%)  C(ResistanceLevel) 431897.24   2.00  3148.12
# 13  Infection Severity (%)            Residual  54671.09 797.00      NaN
# 14              Wilt index  C(ResistanceLevel)   1704.01   2.00  2559.72
# 15              Wilt index            Residual    265.28 797.00      NaN
# 16       Plant height (cm)  C(ResistanceLevel)  59164.83   2.00  1029.46
# 17       Plant height (cm)            Residual  22902.37 797.00      NaN
# 18   Days to wilt symptoms  C(ResistanceLevel)  19281.70   2.00  3800.08
# 19   Days to wilt symptoms            Residual   2022.00 797.00      NaN
# 20       Survival rate (%)  C(ResistanceLevel) 641478.61   2.00  5472.26
# 21       Survival rate (%)            Residual  46713.64 797.00      NaN
# 22   Disease incidence (%)  C(ResistanceLevel) 450696.87   2.00  3899.16
# 23   Disease incidence (%)            Residual  46061.90 797.00      NaN
#
#     p-Value Interpretation
# 0      0.00    Significant
# 1       NaN              -
# 2      0.00    Significant
# 3       NaN              -
# 4      0.00    Significant
# 5       NaN              -
# 6      0.00    Significant
# 7       NaN              -
# 8      0.00    Significant
# 9       NaN              -
# 10     0.00    Significant
# 11      NaN              -
# 12     0.00    Significant
# 13      NaN              -
# 14     0.00    Significant
# 15      NaN              -
# 16     0.00    Significant
# 17      NaN              -
# 18     0.00    Significant
# 19      NaN              -
# 20     0.00    Significant
# 21      NaN              -
# 22     0.00    Significant
# 23      NaN              -

# %% [markdown]
# <h4 style='font-size: 15px; font-weight: 600'>5.4: Tukey's Honest Significant Difference (THSD)</h4>
#
# Now, let's perform Tukey’s Honest Significant Difference (THSD) test to determine which groups are statistically similar or different. While ANOVA tells us if there is a significant difference among groups, it does not specify which groups differ. Tukey’s HSD helps by comparing all possible group pairs and assigning statistical significance to their differences. This step is crucial in identifying which groups share similarities and which ones are distinct, allowing for a more detailed interpretation of the results.

# %%
def Turkey_results(df, Metrics, group=''):
    results_data = []
    for metric in Metrics:
        turkey_results = pairwise_tukeyhsd(endog=df[metric], groups=df[group], alpha=0.05)
        results_table = turkey_results.summary()
        
        for i in range(1, len(results_table)):
            row = results_table.data[i]
            results_data.append({
                'Metric': metric,
                'Group1': row[0],
                'Group2': row[1],
                'Mean Difference': row[2],
                'P-Value': row[3],
                'Lower CI': row[4],
                'Upper CI': row[5],
                'Reject Null': row[6]
            })
        
        result_df = pd.DataFrame(results_data)
    return result_df


Metrics = ['Infection Severity (%)', 'Wilt index', 'Plant height (cm)', 'Days to wilt symptoms', 'Survival rate (%)', 'Disease incidence (%)']
Turkeyresults = Turkey_results(df, Metrics, group='Variety')
pd.set_option("display.float_format", "{:.3f}".format)
Turkeyresults
# Out:
#                      Metric Group1 Group2  Mean Difference  P-Value  Lower CI  \
# 0    Infection Severity (%)  EP-M1  EP-M2            1.270    0.960    -2.294
# 1    Infection Severity (%)  EP-M1  EP-R1          -23.478    0.000   -27.042
# 2    Infection Severity (%)  EP-M1  EP-R2          -23.354    0.000   -26.918
# 3    Infection Severity (%)  EP-M1  EP-R3          -23.273    0.000   -26.837
# 4    Infection Severity (%)  EP-M1  EP-S1           31.092    0.000    27.528
# ..                      ...    ...    ...              ...      ...       ...
# 163   Disease incidence (%)  EP-R3  EP-S2           54.322    0.000    51.054
# 164   Disease incidence (%)  EP-R3  EP-S3           55.547    0.000    52.279
# 165   Disease incidence (%)  EP-S1  EP-S2           -1.672    0.777    -4.940
# 166   Disease incidence (%)  EP-S1  EP-S3           -0.447    1.000    -3.715
# 167   Disease incidence (%)  EP-S2  EP-S3            1.225    0.948    -2.043
#
#      Upper CI  Reject Null
# 0       4.834        False
# 1     -19.914         True
# 2     -19.790         True
# 3     -19.709         True
# 4      34.656         True
# ..        ...          ...
# 163    57.590         True
# 164    58.815         True
# 165     1.596        False
# 166     2.821        False
# 167     4.493        False
#
# [168 rows x 8 columns]

# %%
Metrics = ['Infection Severity (%)', 'Wilt index', 'Plant height (cm)', 'Days to wilt symptoms', 'Survival rate (%)', 'Disease incidence (%)']
Turkeyresults = Turkey_results(df, Metrics, group='Resistance Level')
pd.set_option("display.float_format", "{:.3f}".format)
Turkeyresults
# Out:
#                     Metric     Group1       Group2  Mean Difference  P-Value  \
# 0   Infection Severity (%)   Moderate    Resistant          -24.003    0.000
# 1   Infection Severity (%)   Moderate  Susceptible           29.583    0.000
# 2   Infection Severity (%)  Resistant  Susceptible           53.587    0.000
# 3               Wilt index   Moderate    Resistant           -1.741    0.000
# 4               Wilt index   Moderate  Susceptible            1.629    0.000
# 5               Wilt index  Resistant  Susceptible            3.370    0.000
# 6        Plant height (cm)   Moderate    Resistant           10.185    0.000
# 7        Plant height (cm)   Moderate  Susceptible           -9.673    0.000
# 8        Plant height (cm)  Resistant  Susceptible          -19.859    0.000
# 9    Days to wilt symptoms   Moderate    Resistant            6.233    0.000
# 10   Days to wilt symptoms   Moderate  Susceptible           -5.090    0.000
# 11   Days to wilt symptoms  Resistant  Susceptible          -11.323    0.000
# 12       Survival rate (%)   Moderate    Resistant           34.613    0.000
# 13       Survival rate (%)   Moderate  Susceptible          -30.754    0.000
# 14       Survival rate (%)  Resistant  Susceptible          -65.367    0.000
# 15   Disease incidence (%)   Moderate    Resistant          -25.394    0.000
# 16   Disease incidence (%)   Moderate  Susceptible           29.384    0.000
# 17   Disease incidence (%)  Resistant  Susceptible           54.778    0.000
#
#     Lower CI  Upper CI  Reject Null
# 0    -25.779   -22.228         True
# 1     27.808    31.359         True
# 2     51.999    55.175         True
# 3     -1.865    -1.617         True
# 4      1.505     1.752         True
# 5      3.259     3.481         True
# 6      9.036    11.334         True
# 7    -10.822    -8.524         True
# 8    -20.886   -18.831         True
# 9      5.892     6.575         True
# 10    -5.431    -4.749         True
# 11   -11.629   -11.018         True
# 12    32.972    36.254         True
# 13   -32.395   -29.113         True
# 14   -66.835   -63.899         True
# 15   -27.024   -23.765         True
# 16    27.755    31.014         True
# 17    53.321    56.236         True

# %% [markdown]
# <h4 style='font-size: 15px; font-weight: 600'>5.5: Compact Letter Display (CLD)</h4>
#
# Now, let's compute the **Compact Letter Display (CLD)** across group pairs to summarize the statistical differences between them in a clear and concise table. CLD helps visually represent which groups differ significantly in their means by assigning letters—groups sharing the same letter are not significantly different. This summary makes it easier to interpret multiple pairwise comparisons simultaneously, providing an intuitive overview of group similarities and differences across the dataset.

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
analysis_path = os.path.join(project_root, 'Scripts')
if analysis_path not in sys.path: sys.path.append(analysis_path)

from  compact_letter_display import compact_letter_table

results = compact_letter_table(df, group="Variety", savepath=None)
display(results.T)
# Out:
#                                  EP-M1           EP-M2           EP-R1  \
# Replication ID          50.50 ± 2.90 a  50.50 ± 2.90 a  50.50 ± 2.90 a
# Infection Severity (%)  44.16 ± 1.06 a  45.44 ± 1.01 a  20.69 ± 0.43 c
# Wilt index               2.56 ± 0.07 a   2.51 ± 0.07 a   0.73 ± 0.05 c
# Plant height (cm)       74.44 ± 0.51 a  75.18 ± 0.44 a  84.80 ± 0.59 c
# Days to wilt symptoms   11.99 ± 0.15 a  11.85 ± 0.16 a  17.97 ± 0.19 c
# Survival rate (%)       54.57 ± 1.00 a  55.77 ± 1.00 a  89.25 ± 0.52 c
# Disease incidence (%)   50.54 ± 0.79 a  51.75 ± 1.02 a  25.84 ± 0.72 c
#
#                                  EP-R2           EP-R3           EP-S1  \
# Replication ID          50.50 ± 2.90 a  50.50 ± 2.90 a  50.50 ± 2.90 a
# Infection Severity (%)  20.81 ± 0.46 c  20.89 ± 0.42 c  75.26 ± 1.08 b
# Wilt index               0.83 ± 0.05 c   0.82 ± 0.05 c   4.20 ± 0.06 b
# Plant height (cm)       85.34 ± 0.60 c  84.84 ± 0.58 c  65.22 ± 0.50 b
# Days to wilt symptoms   17.98 ± 0.20 c  18.51 ± 0.20 c   6.82 ± 0.12 b
# Survival rate (%)       90.49 ± 0.46 c  89.61 ± 0.47 c  24.14 ± 0.80 b
# Disease incidence (%)   26.17 ± 0.78 c  25.24 ± 0.70 c  81.24 ± 0.75 b
#
#                                  EP-S2           EP-S3    p-value
# Replication ID          50.50 ± 2.90 a  50.50 ± 2.90 a   1.0000ns
# Infection Severity (%)  73.99 ± 0.91 b  73.91 ± 0.89 b  0.0000***
# Wilt index               4.11 ± 0.05 b   4.18 ± 0.06 b  0.0000***
# Plant height (cm)       65.47 ± 0.54 b  64.71 ± 0.53 b  0.0000***
# Days to wilt symptoms    6.91 ± 0.10 b   6.76 ± 0.12 b  0.0000***
# Survival rate (%)       24.66 ± 0.89 b  24.44 ± 0.75 b  0.0000***
# Disease incidence (%)   79.57 ± 0.65 b  80.79 ± 0.61 b  0.0000***

# %%
results = compact_letter_table(df, group="Resistance Level", savepath=None)
display(results.T)
# Out:
#                               Moderate       Resistant     Susceptible  \
# Replication ID          50.50 ± 2.05 a  50.50 ± 1.67 a  50.50 ± 1.67 a
# Infection Severity (%)  44.80 ± 0.73 b  20.80 ± 0.25 c  74.38 ± 0.56 a
# Wilt index               2.53 ± 0.05 b   0.79 ± 0.03 c   4.16 ± 0.03 a
# Plant height (cm)       74.81 ± 0.33 b  84.99 ± 0.34 c  65.13 ± 0.30 a
# Days to wilt symptoms   11.92 ± 0.11 b  18.15 ± 0.12 c   6.83 ± 0.06 a
# Survival rate (%)       55.17 ± 0.71 b  89.78 ± 0.28 c  24.42 ± 0.47 a
# Disease incidence (%)   51.15 ± 0.64 b  25.75 ± 0.42 c  80.53 ± 0.39 a
#
#                           p-value
# Replication ID           1.0000ns
# Infection Severity (%)  0.0000***
# Wilt index              0.0000***
# Plant height (cm)       0.0000***
# Days to wilt symptoms   0.0000***
# Survival rate (%)       0.0000***
# Disease incidence (%)   0.0000***

# %% [markdown]
# ---
#
# This analysis was performed by **Jabulente**, a passionate and dedicated data analyst with a strong commitment to using data to drive meaningful insights and solutions. For inquiries, collaborations, or further discussions, please feel free to reach out via.
#
# ---
#
# <div align="center">
#
# [![GitHub](https://img.shields.io/badge/GitHub-Jabulente-black?logo=github)](https://github.com/Jabulente)  [![LinkedIn](https://img.shields.io/badge/LinkedIn-Jabulente-blue?logo=linkedin)](https://linkedin.com/in/jabulente-208019349)  [![Email](https://img.shields.io/badge/Email-jabulente@hotmail.com-red?logo=gmail)](mailto:Jabulente@hotmail.com)
#
# </div>

# %% [markdown]
# <h1 style='font-size: 55px; color: red; font-family: Colonna MT; font-weight: 700; text-align: center'>THE END</h1>
